# %%
import Evaluation as eva

# %% [markdown]
# ## Model performance evaluation

# %%
eva.evaluate("LR")
# Out:
# Model:  LR
# Train data
# 0.8744776119402985
# [[1383, 4476], [292, 549]]
# Misclassification error =  841
# SENS(recall)  =  0.7158385093167702
# SPEC   =  0.9387583892617449
# PPV(Precision)   =  0.8256716417910448
# NPV   =  0.8907462686567165
# F1-SCORE =  0.7668422511782645
# AUROC score:  0.9287395828991065
# Test data
# 0.8172727272727273
# [[554, 2143], [249, 354]]
# Misclassification error =  603
# SENS(recall)  =  0.6101321585903083
# SPEC   =  0.8959030100334449
# PPV(Precision)   =  0.6899128268991283
# NPV   =  0.8582298758510212
# F1-SCORE =  0.6475745178258329
# AUROC score:  0.8525435371944661

# %%
eva.evaluate("LR_oversampled",isOverSampled=True)
# Out:
# Model:  LR_oversampled
# Train data
# 0.7628358208955224
# [[5240, 4982], [1745, 1433]]
# Misclassification error =  3178
# SENS(recall)  =  0.7852540086917429
# SPEC   =  0.7405975917942619
# PPV(Precision)   =  0.7501789549033644
# NPV   =  0.7766173031956353
# F1-SCORE =  0.7673158588373115
# AUROC score:  0.8481862403156424
# Test data
# 0.6931818181818182
# [[2347, 2228], [1045, 980]]
# Misclassification error =  2025
# SENS(recall)  =  0.7054403366396153
# SPEC   =  0.6807210510235259
# PPV(Precision)   =  0.6919221698113207
# NPV   =  0.6945137157107232
# F1-SCORE =  0.6986158654561689
# AUROC score:  0.7625122930635118

# %%
eva.evaluate("KD")
# Out:
# Model:  KD
# Test data
# 0.833030303030303
# [[467, 2282], [110, 441]]
# Misclassification error =  551
# SENS(recall)  =  0.51431718061674
# SPEC   =  0.9540133779264214
# PPV(Precision)   =  0.8093587521663779
# NPV   =  0.8380462724935732
# F1-SCORE =  0.6289562289562289
# AUROC score:  0.8595529518365183

# %%
eva.evaluate("KD_oversampled",isOverSampled=True)
# Out:
# Model:  KD_oversampled
# Test data
# 0.5434848484848485
# [[427, 3160], [113, 2900]]
# Misclassification error =  3013
# SENS(recall)  =  0.12834385332131049
# SPEC   =  0.9654750992972808
# PPV(Precision)   =  0.7907407407407407
# NPV   =  0.5214521452145214
# F1-SCORE =  0.2208430307732092
# AUROC score:  0.6332477169500142

# %%
eva.evaluate("RandomForest")
# Out:
# Model:  RandomForest
# Test data
# 0.833939393939394
# [[606, 2146], [246, 302]]
# Misclassification error =  548
# SENS(recall)  =  0.6674008810572687
# SPEC   =  0.8971571906354515
# PPV(Precision)   =  0.7112676056338029
# NPV   =  0.8766339869281046
# F1-SCORE =  0.6886363636363636
# AUROC score:  0.894033019389153

# %%
eva.evaluate("RandomForest_oversampled",isOverSampled=True)
# Out:
# Model:  RandomForest_oversampled
# Test data
# 0.7846969696969697
# [[2679, 2500], [773, 648]]
# Misclassification error =  1421
# SENS(recall)  =  0.8052299368800722
# SPEC   =  0.7638252367858234
# PPV(Precision)   =  0.776071842410197
# NPV   =  0.7941550190597204
# F1-SCORE =  0.7903820622510696
# AUROC score:  0.8539025247879312

# %%
eva.evaluate("SVM")
# Out:
# Model:  SVM
# Train data
# 0.8674626865671642
# [[1339, 4473], [295, 593]]
# Misclassification error =  888
# SENS(recall)  =  0.693064182194617
# SPEC   =  0.9381291946308725
# PPV(Precision)   =  0.8194614443084456
# NPV   =  0.8829451243584682
# F1-SCORE =  0.7509814918676389
# AUROC score:  0.9583399552920088
# Test data
# 0.8384848484848485
# [[574, 2193], [199, 334]]
# Misclassification error =  533
# SENS(recall)  =  0.6321585903083701
# SPEC   =  0.9168060200668896
# PPV(Precision)   =  0.7425614489003881
# NPV   =  0.8678274633953305
# F1-SCORE =  0.6829268292682926
# AUROC score:  0.8678522295316252

# %%
eva.evaluate("SVM_oversampled",isOverSampled=True)
# Out:
# Model:  SVM_oversampled
# Train data
# 0.8305223880597015
# [[5251, 5878], [849, 1422]]
# Misclassification error =  2271
# SENS(recall)  =  0.7869024426794545
# SPEC   =  0.873792180764085
# PPV(Precision)   =  0.8608196721311475
# NPV   =  0.8052054794520548
# F1-SCORE =  0.8222030846316449
# AUROC score:  0.9298086618515146
# Test data
# 0.7306060606060606
# [[2257, 2565], [708, 1070]]
# Misclassification error =  1778
# SENS(recall)  =  0.6783889389840697
# SPEC   =  0.7836846929422548
# PPV(Precision)   =  0.7612141652613827
# NPV   =  0.7056396148555708
# F1-SCORE =  0.7174189446916719
# AUROC score:  0.800470940616686

# %%
eva.evaluate("AlexNet")
# Out:
# D:\anaconda\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model:  AlexNet
# Training data
# 210/210 [==============================] - 39s 168ms/step - loss: 0.1680 - accuracy: 0.9416 - recall: 0.9141 - auc: 0.9829 - false_negatives: 166.0000 - f1_m: 0.8942
# Test data
# 104/104 [==============================] - 20s 189ms/step - loss: 0.3354 - accuracy: 0.8542 - recall: 0.7148 - auc: 0.9129 - false_negatives: 259.0000 - f1_m: 0.7120

# %%
eva.evaluate("AlexNet_oversampled",isOverSampled=True)
# Out:
# Model:  AlexNet_oversampled
# Training data
# 300/300 [==============================] - 59s 170ms/step - loss: 0.1691 - accuracy: 0.9611 - recall: 0.9692 - auc: 0.9934 - false_negatives: 148.0000 - f1_m: 0.9608
# Test data
# 148/148 [==============================] - 28s 188ms/step - loss: 0.4944 - accuracy: 0.7626 - recall: 0.7600 - auc: 0.8496 - false_negatives: 564.0000 - f1_m: 0.7535
